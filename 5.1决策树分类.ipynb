# %%
import pandas as pd
import numpy as np

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"  
names = ['花萼-length', '花萼-width', '花瓣-length', '花瓣-width', 'class'] 

dataset = pd.read_csv(url, names=names)
dataset
# Out:
#      花萼-length  花萼-width  花瓣-length  花瓣-width           class
# 0          5.1       3.5        1.4       0.2     Iris-setosa
# 1          4.9       3.0        1.4       0.2     Iris-setosa
# 2          4.7       3.2        1.3       0.2     Iris-setosa
# 3          4.6       3.1        1.5       0.2     Iris-setosa
# 4          5.0       3.6        1.4       0.2     Iris-setosa
# ..         ...       ...        ...       ...             ...
# 145        6.7       3.0        5.2       2.3  Iris-virginica
# 146        6.3       2.5        5.0       1.9  Iris-virginica
# 147        6.5       3.0        5.2       2.0  Iris-virginica
# 148        6.2       3.4        5.4       2.3  Iris-virginica
# 149        5.9       3.0        5.1       1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
X = dataset.iloc[ : ,[0,1,2,3]].values
Y = dataset.iloc[ : ,  4].values

# %%
from sklearn import tree
from sklearn.datasets import load_iris

clf = tree.DecisionTreeClassifier()  # sk-learn的决策树模型
clf = clf.fit(X, Y)                  # 用数据训练树模型构建()
r   = tree.export_text(clf)#模型决策过程

# %%
text_x = X[[0,1,50,51,100,101], :]
pred_target_prob = clf.predict_proba(text_x)        # 预测类别概率
pred_target = clf.predict(text_x)              # 预测类别

# %%
dataset["预测结果"] = clf.predict(dataset.iloc[:,:4])
dataset.head(10)
# Out:
# D:\Users\40450\anaconda3\lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
#    花萼-length  花萼-width  花瓣-length  花瓣-width        class         预测结果
# 0        5.1       3.5        1.4       0.2  Iris-setosa  Iris-setosa
# 1        4.9       3.0        1.4       0.2  Iris-setosa  Iris-setosa
# 2        4.7       3.2        1.3       0.2  Iris-setosa  Iris-setosa
# 3        4.6       3.1        1.5       0.2  Iris-setosa  Iris-setosa
# 4        5.0       3.6        1.4       0.2  Iris-setosa  Iris-setosa
# 5        5.4       3.9        1.7       0.4  Iris-setosa  Iris-setosa
# 6        4.6       3.4        1.4       0.3  Iris-setosa  Iris-setosa
# 7        5.0       3.4        1.5       0.2  Iris-setosa  Iris-setosa
# 8        4.4       2.9        1.4       0.2  Iris-setosa  Iris-setosa
# 9        4.9       3.1        1.5       0.1  Iris-setosa  Iris-setosa

# %%
print("\n===模型======")
print(r)
print("\n===测试数据：=====")
print(text_x)
print("\n===预测所属类别概率：=====")
print(pred_target_prob)
print("\n===预测所属类别：======")
print(pred_target)
